# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# %cd /content/gdrive/My Drive/02501_ADLCV/02501_advanced_deep_learning_in_computer_vision/
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).
# /content/gdrive/My Drive/02501_ADLCV/02501_advanced_deep_learning_in_computer_vision

# %%
from google.colab.patches import cv2_imshow
import cv2

image_path = "/content/gdrive/My Drive/02501_ADLCV/data/8GrBf4f.png"

image = cv2.imread(image_path)

cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=820x709>
